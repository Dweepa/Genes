# %%
import pandas as pd
import numpy as np
import pickle
from typing import Optional, Union, Tuple
from cmapPy.pandasGEXpress.parse import parse
import numpy as np
import json
from collections import Counter
import sys
from numpy.core.multiarray import ndarray
import sys
import matplotlib.pyplot as plt
import pickle
# Out:
# /Users/dweepa/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
full = pickle.load(open('full','rb'))

# %%
full
# Out:
# rid                         780      7849      6193        23      9552  \
# cid
# REP.A012_HA1E_24H:B12  0.390700 -0.348900  0.617500 -1.761550  0.235550
# REP.A012_HA1E_24H:B10 -0.354954  0.284711 -0.399639 -0.394218  0.269330
# REP.A012_HA1E_24H:B11  0.186348 -0.552110 -1.293667  1.087279  0.009011
# REP.A012_MCF7_24H:B12 -0.409912 -0.012908 -0.357194  0.637424 -0.161387
# REP.A012_MCF7_24H:B08 -0.456875 -0.164637 -0.705794 -0.402885 -2.056623
# REP.A012_YAPC_24H:B09 -0.100060  0.270192 -0.907995 -0.827273 -0.168205
# REP.A012_YAPC_24H:B10  0.444700  0.208320 -0.407552  0.205812 -0.969816
# REP.A012_YAPC_24H:B11  0.544087  0.668740 -1.628970 -0.212949 -0.089287
# REP.A012_YAPC_24H:B12 -0.294442 -0.021309 -0.529232 -0.589263 -1.709425
# REP.A012_A375_24H:B12 -0.114845  0.128724 -0.825713  1.517349 -0.558994
# REP.A012_A375_24H:B11 -0.343964  0.131436 -3.058375  0.634829  0.425165
# REP.A012_A375_24H:B10 -1.069030  0.052967 -0.430402 -0.190381 -1.767261
# ...

# %%
full['signature'] = list(full.index)
full
# Out:
# rid                         780      7849      6193        23      9552  \
# cid
# REP.A012_HA1E_24H:B12  0.390700 -0.348900  0.617500 -1.761550  0.235550
# REP.A012_HA1E_24H:B10 -0.354954  0.284711 -0.399639 -0.394218  0.269330
# REP.A012_HA1E_24H:B11  0.186348 -0.552110 -1.293667  1.087279  0.009011
# REP.A012_MCF7_24H:B12 -0.409912 -0.012908 -0.357194  0.637424 -0.161387
# REP.A012_MCF7_24H:B08 -0.456875 -0.164637 -0.705794 -0.402885 -2.056623
# REP.A012_YAPC_24H:B09 -0.100060  0.270192 -0.907995 -0.827273 -0.168205
# REP.A012_YAPC_24H:B10  0.444700  0.208320 -0.407552  0.205812 -0.969816
# REP.A012_YAPC_24H:B11  0.544087  0.668740 -1.628970 -0.212949 -0.089287
# REP.A012_YAPC_24H:B12 -0.294442 -0.021309 -0.529232 -0.589263 -1.709425
# REP.A012_A375_24H:B12 -0.114845  0.128724 -0.825713  1.517349 -0.558994
# REP.A012_A375_24H:B11 -0.343964  0.131436 -3.058375  0.634829  0.425165
# REP.A012_A375_24H:B10 -1.069030  0.052967 -0.430402 -0.190381 -1.767261
# ...

# %%
all3 = pd.read_csv("./drug_class_identification/phase2/all3_without_nan.csv")

# %%
onlyATCperts = all3.merge(full, left_on='id', right_on='target')

# %%
onlyATCperts.shape
# Out:
# (49373, 986)

# %%
all3.shape
# Out:
# (1004, 6)

# %%
onlyATCperts.columns
# Out:
# Index(['Unnamed: 0', 'smiles', 'name', 'id', 'inchi_key', 'atc', '780', '7849',
#        '6193', '23',
#        ...
#        '6915', '6253', '7264', '5467', '2767', '23038', '57048', '79716',
#        'target', 'signature'],
#       dtype='object', length=986)

# %%
onlyATCperts['signature'].to_csv('signatures_phase2_1004.csv')

# %%
onlyATCperts.to_csv("full_geneexp_phase2_1004.csv")

# %%
df = pd.read_csv("full_geneexp_phase2_1004.csv")

# %%
df[['signature','target']].to_csv("target-signature_phase2_1004.csv")

# %%
def getcellline(x):
    cellline = x.split("_")[1]
    return cellline
df['celline'] = df['signature'].apply(getcellline)
