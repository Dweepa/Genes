# %%
import pandas as pd
import pickle
import requests
import numpy as np
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity as cs
full = pd.read_csv("../data/full_geneexp_phase2_1004.csv")

# %%
cols = ['signature','Unnamed: 0',
 'Unnamed: 0.1',
 'Unnamed: 0.1.1',
 'smiles',
 'name',
 'id',
 'inchi_key',
 'atc']

# %%
full = full.drop(cols, axis=1)

# %%
subset = full[full['celline']=='A375']

# %%
subset = subset.drop(['celline'],axis=1)

# %%
a = list(subset.iloc[0])
b =  list(subset.iloc[1])

# %%
plt.plot(a[:-1])
plt.plot(b[:-1])
plt.show()

# %%
a[-1]
# Out:
# 'BRD-K70330367'

# %%
b[-1]
# Out:
# 'BRD-K70330367'

# %%
max(a[:-1])
# Out:
# 5.210914

# %%
dot = np.dot(np.asarray(a[:-1]),np.asarray(b[:-1]))
norma = np.linalg.norm(a[:-1])
normb = np.linalg.norm(b[:-1])
cos = dot / (norma * normb)
cos
# Out:
# 0.0966926442501046

# %%
c = list(subset[subset['target']=='BRD-K23204545'].iloc[0])

# %%
plt.plot(a[:-1])
plt.plot(c[:-1])
plt.show()

# %%
dot = np.dot(np.asarray(a[:-1]),np.asarray(c[:-1]))
norma = np.linalg.norm(a[:-1])
normb = np.linalg.norm(c[:-1])
cos = dot / (norma * normb)
cos
# Out:
# 0.01879492961278262

# %%
b==c
# Out:
# False
