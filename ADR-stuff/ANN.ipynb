# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
label = pd.read_csv("Datasets/ADR_combined.csv")
pca = pd.read_csv("Datasets/pca_dataset_for_5000_features.csv")
pca.drop("Unnamed: 0", axis=1, inplace = True)
label.drop("Unnamed: 0", axis=1, inplace = True)

# %%
def baseline_model():
    #create model
    model = Sequential()
    model.add(Dense(34549, input_dim=5000, activation='relu'))
    model.add(Dense(10000, activation='relu'))
    model.add(Dense(5000, activation='relu'))
    model.add(Dense(1000, activation='relu'))
    model.add(Dense(243, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model)
    return model
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=10000, verbose=1)
kfold = KFold(n_splits=5, shuffle=True)
results = cross_val_score(estimator, pca, label , cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# ...
# Epoch 1/200
# 27639/27639 [==============================] - 312s 11ms/step - loss: 48325.0787 - accuracy: 7.9598e-04
# Epoch 2/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c47bde38f23b> in <module>
#      13 estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=10000, verbose=1)
#      14 kfold = KFold(n_splits=5, shuffle=True)
# ---> 15 results = cross_val_score(estimator, pca, label , cv=kfold)
#      16 print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# ...

# %%
pca.shape
# Out:
# (34549, 5000)

# %%
model = Sequential()
model.add(Dense(10000, input_dim=5000, activation='relu'))
# model.add(Dense(10000, activation='relu'))
model.add(Dense(5000, activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(243, activation='softmax'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model)

# %%
model.fit(pca.iloc[:10000, :], label.iloc[:10000,:], batch_size=1000, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 10000/10000 [==============================] - 20s 2ms/step - loss: 80879.2676 - accuracy: 0.0012
# Epoch 2/10
# 10000/10000 [==============================] - 20s 2ms/step - loss: 1014249.5781 - accuracy: 0.0013
# Epoch 3/10
# 10000/10000 [==============================] - 20s 2ms/step - loss: 4928140.3000 - accuracy: 7.0000e-04
# Epoch 4/10
# 10000/10000 [==============================] - 21s 2ms/step - loss: 15884068.2000 - accuracy: 0.0048
# Epoch 5/10
# 10000/10000 [==============================] - 23s 2ms/step - loss: 44549603.2000 - accuracy: 0.0161
# Epoch 6/10
#  4000/10000 [===========>..................] - ETA: 14s - loss: 82482616.0000 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-dfc8225cbba6> in <module>
# ----> 1 model.fit(pca.iloc[:10000, :], label.iloc[:10000,:], batch_size=1000, epochs=10, verbose=1)
#
# ...

# %%
pca.iloc[:10000, :]
# Out:
#             PC1        PC2        PC3        PC4        PC5        PC6  \
# 0     -9.722508   6.882401 -28.136658 -11.996354  13.783474 -15.887833
# 1      1.591902  20.986937 -26.549038  -2.369404  12.616441 -16.265122
# 2    -14.391072  -8.375696 -26.025247  -6.607709  12.866812 -17.365116
# 3    -10.642523  -0.253853 -25.697602   2.397817  12.231165 -17.174953
# 4    -16.932294  10.992771 -27.618150  -5.201924  13.693284 -16.404326
# ...         ...        ...        ...        ...        ...        ...
# 9995  12.641798  20.273719  20.487360 -10.774936 -11.803733   6.356843
# 9996  30.539180  49.159058  22.785827   0.605237 -14.796125   5.491867
# 9997 -14.203764   9.341841  22.255102  -4.718769 -13.179654   4.747916
# 9998 -15.851872   4.911982  20.989703 -14.002146 -12.481562   5.186017
# 9999  -5.795699   6.840280  22.019971  -5.032864 -13.156199   4.964593
#
#             PC7        PC8        PC9       PC10  ...        PC4991  \
# ...
